# %% [markdown]
# # Initial Situation

# %% [markdown]
# ![Game Reviews Architecture](pics/GameReviews_Architecture.png)

# %% [markdown]
# In an effort to compare user reviews to journalist reviews and identify potential discrepancies or instances of reviews made in bad faith, we are undertaking a data collection project. This involves gathering a comprehensive dataset of reviews from OpenCritic, focusing initially on reviews authored by journalists from IGN. By systematically retrieving and analyzing this data, we aim to highlight significant differences between professional and user-generated reviews, thereby uncovering any biases or irregularities that may exist within professional reviews. The ultimate goal is to ensure greater transparency and accountability in the review process, fostering a more trustworthy and reliable gaming review ecosystem.

# %% [markdown]
# ## Dependancies

# %%
import json
import requests
import urllib.parse
import pandas as pd

#BeatifulSoup for Webscraping
from bs4 import BeautifulSoup

# Kafka/Spark
from kafka import KafkaProducer
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# In order to compare user review data and journalist data, we first need to gather all this data. We use three different means of gathering data:
#
# - Gather already collected Data that was provided on the internet via CSV-files
#   - Gather Data for 1000 Games
# - Using user created APIs to collect data from a Website:
#   - Gather Outlet Reviews for the 1000 chosen Games, use the API to get the ID for each Game
# - Web Scraping directly using a method
#   - Gather User Reviews for the 1000 chosen Games

# %% [markdown]
# ## Gather 1000 Games

# %% [markdown]
# To start this project, we first need to gather data for 1000 Games which will be the subject of our analysis. To do this, we have taken an existing dataset from Kaggle (https://www.kaggle.com/datasets/arnabchaki/popular-video-games-1980-2023).

# %% [markdown]
# First, we will load the data of this set and check if it was successfull:

# %%
# Load the CSV file
data = pd.read_csv('data/games.csv')

# Display the first few rows of the dataframe to understand its structure
data.head()
# Out:
#    Unnamed: 0                                    Title  Release Date  \
# 0           0                               Elden Ring  Feb 25, 2022
# 1           1                                    Hades  Dec 10, 2019
# 2           2  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3           3                                Undertale  Sep 15, 2015
# 4           4                            Hollow Knight  Feb 24, 2017
#
#                                                 Team  Rating Times Listed  \
# 0     ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                               ['Supergiant Games']     4.3         2.9K
# 2  ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                 ['tobyfox', '8-4']     4.2         3.5K
# 4                                    ['Team Cherry']     4.4           3K
#
#   Number of Reviews                                             Genres  \
# 0              3.9K                               ['Adventure', 'RPG']
# 1              2.9K           ['Adventure', 'Brawler', 'Indie', 'RPG']
# 2              4.3K                               ['Adventure', 'RPG']
# 3              3.5K  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...
# 4                3K                 ['Adventure', 'Indie', 'Platform']
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  A rogue-lite hack and slash dungeon crawler in...
# 2  The Legend of Zelda: Breath of the Wild is the...
# 3  A small child falls into the Underground, wher...
# 4  A 2D metroidvania with an emphasis on close co...
#
#                                              Reviews Plays Playing Backlogs  \
# 0  ["The first playthrough of elden ring is one o...   17K    3.8K     4.6K
# 1  ['convinced this is a roguelike for people who...   21K    3.2K     6.3K
# 2  ['This game is the game (that is not CS:GO) th...   30K    2.5K       5K
# 3  ['soundtrack is tied for #1 with nier automata...   28K     679     4.9K
# 4  ["this games worldbuilding is incredible, with...   21K    2.4K     8.3K
#
#   Wishlist
# 0     4.8K
# 1     3.6K
# 2     2.6K
# 3     1.8K
# 4     2.3K

# %% [markdown]
# Now let's check if there are any empty Datasets at points where we actually need data:

# %%
# Check for empty strings in the "Title" and "Team" columns
empty_names = data['Title'].isna().sum()
empty_publishers = data['Team'].isna().sum()

empty_names, empty_publishers
# Out:
# (0, 1)

# %% [markdown]
# Seems like there is only one missing value in "Team", let's remove that:

# %%
# Remove rows with empty "publisher" values
data_cleaned = data.dropna(subset=['Team'])

# Verify that the rows with empty "publisher" values have been removed
empty_publishers_after_cleanup = data_cleaned['Team'].isna().sum()
empty_publishers_after_cleanup
# Out:
# 0

# %% [markdown]
# Now let's check for duplicates:

# %%
# Find duplicated titles
duplicated_titles = data_cleaned[data_cleaned.duplicated(subset=['Title'], keep=False)]

# Count the number of duplicates for each title
duplicate_counts = duplicated_titles['Title'].value_counts()

# Display the counts of duplicated titles
print("\nCounts of Duplicated Titles:")
print(duplicate_counts)
# Out:
# Counts of Duplicated Titles:
# Title
# Doom                               7
# Dead Space                         5
# Shadow of the Colossus             5
# Resident Evil 2                    5
# Demon's Souls                      4
#                                   ..
# Mass Effect Legendary Edition      2
# Helltaker                          2
# Pokémon Sword                      2
# Crash Bandicoot N. Sane Trilogy    2
# FIFA 13                            2
# Name: count, Length: 279, dtype: int64

# %% [markdown]
# Seems like the dataset also has a few duplicates where we don't want any, lets remove them:

# %%
# Count the number of items in the 'Title' column for data_cleaned
total_titles_before = data_cleaned['Title'].count()

# Drop duplicates based on the 'Title' column
unique_games = data_cleaned.drop_duplicates(subset='Title')

# Count the number of items in the 'Title' column for unique_games
total_titles_after = unique_games['Title'].count()

# Print the counts before and after cleaning
print(f"Number of items in 'Title' column before cleaning: {total_titles_before}")
print(f"Number of items in 'Title' column after cleaning: {total_titles_after}")
# Out:
# Number of items in 'Title' column before cleaning: 1511
# Number of items in 'Title' column after cleaning: 1098

# %% [markdown]
# Seems like the data is now good, we will save the Game Titles:

# %%
# Extract the first 1000 entries from the "name" column
game_names = unique_games['Title'].tolist()
game_names[:10] # Display the first 10 names to verify the extractin
# Out:
# ['Elden Ring',
#  'Hades',
#  'The Legend of Zelda: Breath of the Wild',
#  'Undertale',
#  'Hollow Knight',
#  'Minecraft',
#  'Omori',
#  'Metroid Dread',
#  'Among Us',
#  'NieR: Automata']

# %%
# Also extract the first 1000 entries for publishers
game_publisher = unique_games['Team'].tolist()
game_publisher[:10]
# Out:
# ["['Bandai Namco Entertainment', 'FromSoftware']",
#  "['Supergiant Games']",
#  "['Nintendo', 'Nintendo EPD Production Group No. 3']",
#  "['tobyfox', '8-4']",
#  "['Team Cherry']",
#  "['Mojang Studios']",
#  "['OMOCAT', 'PLAYISM']",
#  "['Nintendo', 'MercurySteam']",
#  "['InnerSloth']",
#  "['PlatinumGames', 'Square Enix']"]

# %% [markdown]
# ## OpenCritic API

# %% [markdown]
# OpenCritic is a Website that hosts Reviews from journalists. With this API, we can filter for certain categories, most importantly via the author id. With this, we can collect a certain amount of review scores from different media outlets.
# We will be collecting 1000 datasets for each of the following 10 media outlets, including their id used for the API filtering:
#
# - IGN (56)
# - PC Gamer (162)
# - GamesRadar+ (91)
# - Metro GameCentral (75)
# - Eurogamer (114)
# - Easy Allies (394)
# - Game Informer (35)
# - Polygon (87)
# - GameSpot (32)
# - Kotaku (276)

# %% [markdown]
# First, we need to gather the OpenCritic game ID for each game we want the review score of, to do that, we iterate through our games array and send each string to the API to search for the game ID:

# %%
# API key used for the API access
api_key = "64686b9a75msha576b74f8ff0b56p1a63ebjsnf20f69b4fac9"

# Function to get game IDs
def get_game_ids(game_names, api_key):
    all_game_ids = []
    filtered_game_names = []

    for game_name in game_names:
        encoded_game_name = urllib.parse.quote(game_name)
        url = f"https://opencritic-api.p.rapidapi.com/game/search?criteria={encoded_game_name}"

        headers = {
            "X-RapidAPI-Host": "opencritic-api.p.rapidapi.com",
            "X-RapidAPI-Key": api_key
        }

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            if data:
                # Check if the name of the top search result matches the game name exactly
                top_game = data[0]
                if top_game['name'].lower() == game_name.lower():
                    top_game_id = top_game['id']
                    all_game_ids.append((game_name, top_game_id))
                    filtered_game_names.append(game_name)
                    print(f"Game ID for '{game_name}' is {top_game_id}")
                else:
                    print(f"No exact match found for '{game_name}'")
            else:
                print(f"No results found for '{game_name}'")
        else:
            print(f"Error searching for '{game_name}': ", response.status_code)

    return filtered_game_names, all_game_ids

# Call the method
filtered_game_names, game_ids = get_game_ids(game_names, api_key)

# Save game IDs to JSON file
data = {"filtered_game_names": filtered_game_names, "game_ids": game_ids}
with open("data/game_ids.json", "w") as json_file:
    json.dump(data, json_file)

print("Game IDs saved to data/game_ids.json")
# Out:
# Game ID for 'Elden Ring' is 12090
# Game ID for 'Hades' is 10181
# Game ID for 'The Legend of Zelda: Breath of the Wild' is 1548
# Game ID for 'Undertale' is 1907
# Game ID for 'Hollow Knight' is 4002
# Game ID for 'Minecraft' is 194
# Game ID for 'Omori' is 10743
# Game ID for 'Metroid Dread' is 11621
# Game ID for 'Among Us' is 10238
# Game ID for 'NieR: Automata' is 3540
# Game ID for 'Persona 5 Royal' is 8785
# Game ID for 'Stray' is 13386
# Game ID for 'God of War' is 5434
# No exact match found for 'Portal 2'
# Game ID for 'Bloodborne' is 76
# Game ID for 'Celeste' is 5403
# Game ID for 'Yakuza 0' is 3387
# Game ID for 'Red Dead Redemption 2' is 3717
# No exact match found for 'Portal'
# Game ID for 'Super Mario Odyssey' is 4504
# Game ID for 'Pokémon Legends: Arceus' is 12091
# Game ID for 'Hi-Fi Rush' is 14227
# Game ID for 'Metal Gear Rising: Revengeance' is 1014
# Game ID for 'Grand Theft Auto V' is 163
# Game ID for 'Cyberpunk 2077' is 8525
# Game ID for 'God of War Ragnarök' is 12919
# Game ID for 'Xenoblade Chronicles 3' is 13148
# Game ID for 'Kirby and the Forgotten Land' is 12682
# Game ID for 'Disco Elysium: The Final Cut' is 11148
# Game ID for 'Marvel's Spider-Man' is 6012
# Game ID for 'Dark Souls III' is 1520
# No exact match found for 'NieR Replicant ver.1.22474487139...'
# No exact match found for 'Super Mario 64'
# Game ID for 'Super Smash Bros. Ultimate' is 6223
# Game ID for 'Cuphead' is 1792
# Game ID for 'Sekiro: Shadows Die Twice' is 6630
# Game ID for 'Final Fantasy VII' is 1566
# Game ID for 'Persona 4 Golden' is 9636
# Game ID for 'Genshin Impact' is 10217
# Game ID for 'Signalis' is 13889
# Game ID for 'Resident Evil Village' is 10995
# No exact match found for 'Super Mario Galaxy'
# No exact match found for 'Fallout: New Vegas'
# Game ID for 'Outer Wilds' is 7815
# No exact match found for 'Kirby's Adventure'
# Game ID for 'Tekken 7' is 3599
# No exact match found for 'Umineko: When They Cry Chiru'
# No exact match found for 'Kingdom Hearts II Final Mix'
# Game ID for 'Superliminal' is 8533
# No exact match found for 'Death Stranding: Director's Cut'
# No exact match found for 'Persona 4'
# Game ID for 'Wordle' is 12693
# Game ID for 'The Sims 4' is 572
# Game ID for 'Far Cry 4' is 159
# Game ID for 'Sonic Forces' is 4793
# Game ID for 'To the Moon' is 8836
# Game ID for 'Baba is You' is 7457
# No exact match found for 'The Witcher 3: Wild Hunt - Game of the Year Edition'
# No exact match found for 'Super Smash Bros.'
# No exact match found for 'Super Mario 64 DS'
# No exact match found for 'Halo 4'
# Game ID for 'Middle-earth: Shadow of Mordor' is 201
# No exact match found for 'Mega Man 2'
# Game ID for 'Phoenix Wright: Ace Attorney Trilogy' is 7083
# Game ID for 'Infamous: Second Son' is 278
# Game ID for 'Star Wars: Knights of the Old Republic' is 12313
# Game ID for 'No More Heroes 2: Desperate Struggle' is 10473
# No exact match found for 'Kirby Super Star Ultra'
# No exact match found for 'Flower, Sun, and Rain'
# No exact match found for 'Katamari Damacy'
# No exact match found for 'Shadow the Hedgehog'
# No exact match found for 'Ōkami HD'
# Game ID for 'Metroid: Samus Returns' is 4498
# Game ID for 'Life is Strange: True Colors' is 11319
# No exact match found for 'Pokémon Black Version 2'
# Game ID for 'Needy Streamer Overload' is 12677
# No exact match found for 'Borderlands'
# Game ID for 'Hollow Knight: Voidheart Edition' is 6664
# No exact match found for 'Klonoa: Door to Phantomile'
# Game ID for 'Shadow of the Tomb Raider' is 6015
# No exact match found for 'Mario & Luigi: Bowser's Inside Story'
# Game ID for 'Ghostrunner' is 10172
# Game ID for 'Watch Dogs 2' is 2846
# No exact match found for 'Mass Effect 3'
# Game ID for 'Goat Simulator' is 335
# Game ID for 'The Elder Scrolls V: Skyrim - Special Edition' is 2851
# Game ID for 'Far Cry 5' is 4384
# No exact match found for 'Call of Duty: Modern Warfare 3'
# No exact match found for 'Friday Night Funkin''
# No exact match found for 'Osu!'
# No exact match found for 'The Legend of Zelda: Twilight Princess'
# Game ID for 'Bloodborne: The Old Hunters' is 1890
# Game ID for 'Fire Emblem Warriors: Three Hopes' is 13146
# Game ID for 'Super Smash Bros. for Nintendo 3DS' is 2349
# Game ID for 'The Legend of Heroes: Trails to Azure' is 14398
# No exact match found for 'Super Mario RPG: Legend of the Seven Stars'
# Game ID for 'Astral Chain' is 7870
# No exact match found for 'DmC: Devil May Cry'
# No exact match found for 'Dragon Age: Origins'
# No exact match found for 'Vagrant Story'
# No exact match found for 'Amnesia: The Dark Descent'
# Game ID for 'Monster Hunter Rise: Sunbreak' is 13169
# Game ID for 'Super Mario Maker 2' is 7760
# No exact match found for 'Fire Emblem: The Blazing Blade'
# Game ID for 'LEGO Marvel Super Heroes' is 307
# No exact match found for 'Sonic Colors'
# No exact match found for 'Pokémon Moon'
# No exact match found for 'Zelda II: The Adventure of Link'
# Game ID for 'Battlefield 4' is 317
# Game ID for 'Gorogoa' is 1588
# Game ID for 'Valkyrie Elysium' is 13381
# No exact match found for 'Castlevania: Order of Ecclesia'
# No exact match found for 'Deadly Premonition'
# No exact match found for 'LEGO Batman 2: DC Super Heroes'
# Game ID for 'Lunistice' is 13979
# No exact match found for 'Sonic Advance'
# No exact match found for 'Metal Slug'
# Game ID for 'Just Cause 3' is 1528
# No exact match found for 'Suikoden II'
# No exact match found for 'LittleBigPlanet'
# Game ID for 'EarthBound Beginnings' is 12763
# No exact match found for 'Wario Land 3'
# Game ID for 'Faith: The Unholy Trinity' is 13890
# No exact match found for 'Tales of Symphonia'
# No exact match found for 'The Dark Pictures Anthology: Man of Medan'
# No exact match found for 'Saya no Uta'
# Game ID for 'River City Girls' is 8213
# Game ID for 'Sonic Origins' is 13269
# No exact match found for 'Kuru Kuru Kururin'
# Game ID for 'Pikmin 2' is 15133
# No exact match found for 'Wonderful Everyday: Down the Rabbit-Hole'
# Game ID for 'Paper Mario: The Origami King' is 9585
# No exact match found for 'Conker's Bad Fur Day'
# No exact match found for 'Fire Emblem: Radiant Dawn'
# No exact match found for 'Need for Speed: Heat'
# No exact match found for 'Skate 3'
# No exact match found for 'Braid'
# No exact match found for 'Metro 2033'
# No exact match found for 'Another Pokémon Game'
# Game ID for 'Super Mario Party' is 6224
# Game ID for 'Kentucky Route Zero' is 3014
# Game ID for 'The Legend of Zelda: Twilight Princess HD' is 2125
# No exact match found for 'We Love Katamari'
# No exact match found for 'Serial Experiments Lain'
# No exact match found for 'Kirby's Dream Land 2'
# Game ID for 'Harvestella' is 13949
# Game ID for 'Dishonored: Death of the Outsider' is 4613
# No exact match found for 'Life is Strange 2'
# No exact match found for 'Banjo-Tooie'
# Game ID for 'The Legend of Zelda: Oracle of Ages' is 15304
# Game ID for 'Lobotomy Corporation' is 5924
# No exact match found for 'Saints Row 2'
# Game ID for 'Final Fantasy VII Rebirth' is 15136
# No exact match found for 'Castlevania: Bloodlines'
# Game ID for 'Tiny Tina's Wonderlands' is 12353
# Game ID for 'Utawarerumono: Mask of Truth' is 4773
# No exact match found for 'Hitman World of Assassination'
# No exact match found for 'Just Cause 2'
# Game ID for 'Lies of P' is 15437
# Game ID for 'Final Fantasy V' is 1821
# No exact match found for 'Jet Set Radio Future'
# No exact match found for 'Overcooked!'
# Game ID for 'Shin Megami Tensei IV: Apocalypse' is 3276
# Game ID for 'Muse Dash' is 7902
# No exact match found for 'Fire Emblem: Genealogy of the Holy War'
# No exact match found for 'Judas'
# No exact match found for 'Half-Life: Opposing Force'
# No exact match found for 'Bloodborne PSX'
# No exact match found for 'Prototype'
# No exact match found for 'Pokémon Gold'
# Game ID for 'Valheim' is 12081
# No exact match found for 'Your Turn To Die: Death Game By Majority'
# No exact match found for 'Gal Guardians: Demon Purge'
# Game ID for 'Mortal Shell' is 10021
# Game ID for 'Kingdom Come: Deliverance' is 1561
# Game ID for 'Sleeping Dogs: Definitive Edition' is 189
# Game ID for 'Ori and the Will of the Wisps' is 7403
# No exact match found for 'Mass Effect'
# Game ID for 'Return of the Obra Dinn' is 1726
# Game ID for 'Kingdom Hearts III' is 1532
# No exact match found for 'Fallout 3'
# No exact match found for 'Uncharted: Drake's Fortune'
# No exact match found for 'Zero Escape: Nine Hours, Nine Persons, Nine Doors'
# Game ID for 'Lost Judgment' is 11984
# No exact match found for 'Super Mario 3D Land'
# Game ID for 'Gris' is 6890
# No exact match found for 'Silent Hill 3'
# No exact match found for 'Call of Duty: Modern Warfare 2'
# No exact match found for 'The Walking Dead: Season One'
# No exact match found for 'Mario Kart DS'
# Game ID for 'Apex Legends' is 7267
# Game ID for 'Devil May Cry 2' is 8501
# No exact match found for 'The Legend of Zelda: Ocarina of Time 3D'
# No exact match found for 'Twelve Minutes'
# Game ID for 'Rayman Legends' is 288
# No exact match found for 'Uncharted 2: Among Thieves'
# No exact match found for 'Monster Hunter: World'
# No exact match found for 'Milk inside a bag of milk inside a bag of milk'
# Game ID for 'The Legend of Zelda: A Link Between Worlds' is 2405
# Game ID for 'Final Fantasy XIV: Endwalker' is 11626
# No exact match found for 'The Legend of Zelda: The Minish Cap'
# No exact match found for 'Pokémon Go'
# Game ID for 'Night in the Woods' is 1685
# No exact match found for 'Shin Megami Tensei IV'
# No exact match found for 'Kingdom Hearts II'
# No exact match found for 'Castlevania: Aria of Sorrow'
# No exact match found for 'Halo: Reach'
# No exact match found for 'Grand Theft Auto: Vice City'
# Game ID for 'A Short Hike' is 8025
# Game ID for 'The Legend of Zelda: Tears of the Kingdom' is 14343
# No exact match found for 'Assassin's Creed III'
# No exact match found for 'Castlevania'
# No exact match found for 'Milk outside a bag of milk outside a bag of milk'
# No exact match found for 'Lisa'
# No exact match found for 'Crash Bandicoot'
# No exact match found for 'The Legend of Zelda: The Wind Waker HD'
# Game ID for 'The Outer Worlds' is 7413
# Game ID for 'The Legend of Zelda: Majora's Mask 3D' is 2284
# Game ID for 'The Callisto Protocol' is 13372
# No exact match found for 'The Wolf Among Us'
# No exact match found for 'Dead Space 2'
# No exact match found for 'Super Mario Bros. 2'
# Game ID for 'Until Dawn' is 1832
# No exact match found for 'Kid Icarus: Uprising'
# Game ID for 'Chained Echoes' is 14102
# Game ID for 'BioShock Remastered' is 9556
# No exact match found for 'Sonic Unleashed'
# Game ID for 'Yakuza 5 Remastered' is 8677
# No exact match found for 'Metal Gear Solid 3: Subsistence'
# No exact match found for 'Super Mario World 2: Yoshi's Island'
# No exact match found for 'Devil May Cry 4'
# Game ID for 'Donut County' is 1735
# Game ID for 'Assassin's Creed Origins' is 4503
# Game ID for 'Ghostwire: Tokyo' is 12720
# Game ID for 'Yakuza 4 Remastered' is 8561
# No exact match found for 'Call of Duty: Modern Warfare II'
# Game ID for 'Crash Bandicoot 4: It's About Time' is 9900
# Game ID for 'Grand Theft Auto III' is 12065
# Game ID for 'Dead by Daylight' is 2844
# Game ID for 'Abzu' is 1607
# No exact match found for 'Batman: Arkham Origins'
# Game ID for 'Splatoon 2' is 4214
# No exact match found for 'Pokémon HeartGold'
# Game ID for 'Kena: Bridge of Spirits' is 11516
# No exact match found for 'Final Fantasy VIII'
# No exact match found for 'The Elder Scrolls IV: Oblivion'
# Game ID for 'The Silver Case' is 3427
# No exact match found for 'Marvel's Spider-Man Remastered'
# Game ID for 'Alan Wake' is 10047
# Game ID for 'A Way Out' is 5413
# No exact match found for 'LEGO Batman: The Video Game'
# Game ID for 'Borderlands 3' is 7656
# Game ID for 'Dragon Ball FighterZ' is 5273
# No exact match found for 'Ico'
# No exact match found for 'Shin Megami Tensei III: Nocturne - HD Remaster'
# Game ID for 'The Witness' is 1557
# No exact match found for 'Animal Crossing: New Leaf'
# Game ID for 'Wo Long: Fallen Dynasty' is 14367
# Game ID for 'Final Fantasy VII Remake Intergrade' is 11370
# No exact match found for 'Sonic Adventure 2'
# Game ID for 'Destiny 2' is 4139
# No exact match found for 'Kirby's Dream Land'
# Game ID for 'Mario Kart 8' is 1064
# No exact match found for 'Xenoblade Chronicles'
# Game ID for 'The Forgotten City' is 11732
# Game ID for 'Untitled Goose Game' is 8308
# No exact match found for 'Sonic Adventure 2: Battle'
# No exact match found for 'Saints Row: The Third'
# Game ID for 'Call of Duty: Black Ops III' is 1514
# No exact match found for 'Pokémon Red'
# Game ID for 'Tinykin' is 13576
# Game ID for 'Dragon's Dogma: Dark Arisen' is 2141
# Game ID for 'Brawlhalla' is 5034
# No exact match found for 'Pokémon Unite'
# Game ID for 'Black Mesa' is 9106
# Game ID for 'The Messenger' is 6521
# No exact match found for 'Jet Set Radio'
# Game ID for 'Pathologic 2' is 7756
# Game ID for 'Tactics Ogre: Reborn' is 13974
# Game ID for 'Hyper Light Drifter' is 1558
# No exact match found for 'Left 4 Dead'
# Game ID for 'The 25th Ward: The Silver Case' is 5685
# Game ID for 'Darkest Dungeon' is 1567
# Game ID for 'Roblox' is 1927
# Game ID for 'The Last Guardian' is 1524
# No exact match found for 'Drakengard 3'
# No exact match found for 'Half-Life 2: Episode One'
# No exact match found for 'Assassin's Creed Revelations'
# No exact match found for 'Half-Life 2: Episode Two'
# No exact match found for 'Mega Man'
# Game ID for 'PowerWash Simulator' is 11395
# No exact match found for 'Cave Story'
# Game ID for 'Final Fantasy XIV: Shadowbringers' is 7836
# Game ID for 'Days Gone' is 6846
# Game ID for 'Tom Clancy's Rainbow Six Siege' is 1526
# Game ID for 'Trek to Yomi' is 13107
# No exact match found for 'Sonic CD'
# No exact match found for 'Mario Kart: Double Dash!!'
# No exact match found for 'Rayman Origins'
# Game ID for 'Klonoa Phantasy Reverie Series' is 13345
# Game ID for 'Hitman 2' is 6215
# Game ID for 'Max Payne 3' is 11698
# Game ID for 'Catherine: Full Body' is 7771
# Game ID for 'Kirby: Planet Robobot' is 2732
# Game ID for 'Battlefield 1' is 2835
# No exact match found for 'Kirby’s Return to Dream Land Deluxe'
# No exact match found for 'Persona 2: Eternal Punishment'
# No exact match found for 'Star Wars Battlefront II'
# No exact match found for 'Super Paper Mario'
# No exact match found for 'The Great Ace Attorney 2: Resolve'
# Game ID for 'Bugsnax' is 10498
# No exact match found for 'Star Wars: Battlefront II'
# No exact match found for 'Pokémon Shield'
# No exact match found for 'Super Castlevania IV'
# Game ID for 'Brothers: A Tale of Two Sons' is 1867
# Game ID for 'Call of Duty: Modern Warfare' is 7398
# Game ID for 'GoldenEye 007' is 14240
# No exact match found for 'WarioWare, Inc.: Mega Microgames!'
# Game ID for 'Evil West' is 13378
# Game ID for 'Gravity Rush 2' is 3383
# No exact match found for 'Metroid Prime 2: Echoes'
# Game ID for 'The Forest' is 6029
# Game ID for 'CrossCode' is 6635
# No exact match found for 'Sekiro: Shadows Die Twice - GOTY Edition'
# No exact match found for 'Saints Row IV'
# No exact match found for 'Fallout 2'
# No exact match found for 'Chrono Cross'
# No exact match found for 'Fire Emblem: Path of Radiance'
# No exact match found for 'Kingdom Hearts Final Mix'
# No exact match found for 'Professor Layton and the Curious Village'
# Game ID for 'Ys VIII: Lacrimosa of Dana' is 4757
# No exact match found for 'Hotel Dusk: Room 215'
# No exact match found for 'Postal 2'
# Game ID for 'Fez' is 276
# Game ID for 'Marvel's Midnight Suns' is 13373
# Game ID for 'Streets of Rage 4' is 9380
# No exact match found for 'Shin Megami Tensei: Persona'
# No exact match found for 'Kirby's Return to Dream Land'
# No exact match found for 'BioShock 2 Remastered'
# No exact match found for 'God of War: Chains of Olympus'
# Game ID for 'Splatoon' is 709
# Game ID for 'Nickelodeon All-Star Brawl' is 12045
# No exact match found for 'The Great Ace Attorney: Adventures'
# No exact match found for 'Sonic Rush'
# Game ID for 'Street Fighter V' is 1640
# Game ID for 'Somerville' is 13961
# No exact match found for 'Bully: Scholarship Edition'
# Game ID for 'Borderlands: The Pre-Sequel' is 942
# Game ID for 'Star Wars Jedi: Survivor' is 14199
# No exact match found for 'Alice: Madness Returns'
# Game ID for 'Super Mario 3D All-Stars' is 10104
# No exact match found for 'S.T.A.L.K.E.R.: Shadow of Chernobyl'
# No exact match found for 'JoJo’s Bizarre Adventure: All-Star Battle R'
# No exact match found for 'Geometry Dash'
# No exact match found for 'Mario + Rabbids Sparks of Hope'
# Game ID for 'Back 4 Blood' is 12078
# Game ID for 'Half-Life: Alyx' is 8996
# Game ID for 'Hyper Demon' is 13711
# No exact match found for 'Mortal Kombat'
# Game ID for 'Call of Duty: Ghosts' is 304
# Game ID for 'Ridge Racer Type 4' is 14472
# Game ID for 'Lil Gator Game' is 14120
# Game ID for 'Oxenfree' is 2142
# No exact match found for 'Overcooked! 2'
# Game ID for 'Before Your Eyes' is 11176
# No exact match found for 'Sly Cooper and the Thievius Raccoonus'
# Game ID for 'Nobody Saves the World' is 12611
# No exact match found for 'Crazy Taxi'
# Game ID for 'Chrono Cross: The Radical Dreamers Edition' is 12976
# No exact match found for 'Spore'
# Game ID for 'Dwarf Fortress' is 14083
# No exact match found for 'Klonoa 2: Lunatea's Veil'
# No exact match found for 'Pokémon Blue'
# Game ID for 'Tomodachi Life' is 2358
# Game ID for 'Downwell' is 1966
# No exact match found for 'SpongeBob SquarePants: Battle For Bikini Bottom'
# No exact match found for 'LEGO Harry Potter: Years 1-4'
# No exact match found for 'Dragon Quest V: Hand of the Heavenly Bride'
# No exact match found for 'Fear & Hunger'
# Game ID for 'For Honor' is 2863
# No exact match found for 'Sonic Lost World'
# Game ID for 'Bug Fables: The Everlasting Sapling' is 9458
# Game ID for 'Hyrule Warriors: Age of Calamity' is 10157
# Game ID for 'LEGO Batman 3: Beyond Gotham' is 166
# Game ID for 'Moonscars' is 13731
# Game ID for 'The Witcher 3: Wild Hunt - Hearts of Stone' is 1827
# Game ID for 'Remnant: From the Ashes' is 7966
# Game ID for 'Halo 5: Guardians' is 1513
# No exact match found for 'Hearthstone'
# No exact match found for 'Ultimate Spider-Man'
# Game ID for 'Chop Goblins' is 14130
# No exact match found for 'Secret of Mana'
# Game ID for '428: Shibuya Scramble' is 6543
# Game ID for 'Potion Craft' is 12040
# No exact match found for 'Mega Man Legends'
# No exact match found for 'Xenoblade Chronicles: Future Connected'
# Game ID for 'Crab Game' is 12385
# No exact match found for 'Dante's Inferno'
# No exact match found for 'Haunting Ground'
# Game ID for 'Assassin's Creed Rogue' is 1396
# Game ID for 'Garten of Banban 2' is 16880
# Game ID for 'Pokémon Stadium' is 14781
# Game ID for 'Outlast II' is 4124
# Game ID for 'Elden Ring: Shadow of the Erdtree' is 16525
# No exact match found for 'Ni no Kuni II: Revenant Kingdom'
# No exact match found for 'Metal Gear'
# No exact match found for 'Disney's Aladdin'
# No exact match found for 'Fable II'
# No exact match found for 'Celeste: Farewell'
# Game ID for 'Axiom Verge 2' is 11805
# Game ID for 'Lightning Returns: Final Fantasy XIII' is 2042
# No exact match found for 'Yakuza 2'
# Game ID for 'F-Zero X' is 12882
# No exact match found for 'Chibi-Robo!'
# Game ID for 'RimWorld' is 6905
# No exact match found for 'Professor Layton and the Miracle Mask'
# No exact match found for 'Mega Man X5'
# No exact match found for 'Tokyo Necro'
# Game ID for 'Disney Dreamlight Valley' is 13635
# No exact match found for 'Mega Man 7'
# Game ID for 'Figment' is 4894
# No exact match found for 'Flower, Sun, and Rain: Murder and Mystery in Paradise'
# No exact match found for 'Professor Layton vs. Phoenix Wright: Ace Attorney'
# No exact match found for 'Metal Gear Solid: The Twin Snakes'
# No exact match found for 'The Simpsons Game'
# No exact match found for 'Mega Man Zero 2'
# Game ID for 'Gears 5' is 7402
# No exact match found for 'Crash of the Titans'
# Game ID for 'Alan Wake Remastered' is 12067
# Game ID for 'Final Fantasy XV: Royal Edition' is 5699
# No exact match found for 'The Witcher'
# Game ID for 'Final Fantasy III' is 529
# No exact match found for 'Snatcher'
# No exact match found for 'Hello Charlotte Ep.3: Childhood's End'
# No exact match found for 'Star Wars: Battlefront'
# Game ID for 'Ikaruga' is 6133
# Game ID for 'Diablo IV' is 14353
# No exact match found for 'Ys: The Oath in Felghana'
# No exact match found for 'American McGee's Alice'
# No exact match found for 'Toy Story 2: Buzz Lightyear to the Rescue!'
# No exact match found for 'Rayman Raving Rabbids'
# No exact match found for 'Prototype 2'
# No exact match found for 'MadWorld'
# No exact match found for 'Call of Duty 3'
# Game ID for 'Shadow Warrior' is 181
# No exact match found for 'Warcraft III: The Frozen Throne'
# No exact match found for 'Yakuza 4'
# No exact match found for 'Megami Ibunroku Persona'
# No exact match found for 'Persona 4 Arena'
# No exact match found for 'Scribblenauts'
# No exact match found for 'Rock Band 2'
# No exact match found for 'Armored Core 4'
# Game ID for 'Rez Infinite' is 3379
# No exact match found for 'Plants vs. Zombies 2: It's About Time'
# Game ID for 'Cadence of Hyrule: Crypt of the NecroDancer Featuring the Legend of Zelda' is 7886
# No exact match found for '100% Orange Juice'
# No exact match found for 'Tekken 6'
# No exact match found for 'Mortal Kombat 3'
# No exact match found for 'Pokémon Mystery Dungeon: Explorers of Time'
# No exact match found for 'Chulip'
# No exact match found for 'Crash Nitro Kart'
# No exact match found for 'Bubble Bobble'
# Game ID for 'Shantae: Half-Genie Hero' is 3126
# No exact match found for 'Snake'
# No exact match found for 'Tales of Vesperia'
# No exact match found for 'Mega Man X8'
# No exact match found for 'Fire Emblem: New Mystery of the Emblem'
# Game ID for 'Mario & Luigi: Superstar Saga + Bowser's Minions' is 4959
# No exact match found for 'Suikoden'
# Game ID for 'Binary Domain' is 12631
# No exact match found for 'Shin Megami Tensei: Devil Survivor'
# Game ID for 'JoJo's Bizarre Adventure: Eyes of Heaven' is 2885
# No exact match found for 'Audiosurf'
# No exact match found for 'Better Call Saul Kart'
# No exact match found for 'The Secret of Monkey Island'
# No exact match found for 'Resistance: Fall of Man'
# Game ID for 'Sniper Elite 4' is 3497
# No exact match found for 'Metal Gear Solid HD Collection'
# No exact match found for 'The Simpsons: Road Rage'
# No exact match found for 'Melty Blood Actress Again Current Code'
# No exact match found for 'Path of Exile'
# Game ID for 'Machinarium' is 9310
# No exact match found for 'Guacamelee!'
# Game ID for 'Tales of Zestiria' is 1702
# No exact match found for 'Black'
# No exact match found for 'Mario Super Sluggers'
# No exact match found for 'Worms Armageddon'
# No exact match found for 'Street Fighter II Turbo'
# No exact match found for 'Tekken 4'
# No exact match found for 'Legacy of Kain: Soul Reaver'
# No exact match found for 'Mega Man X7'
# No exact match found for 'Final Fantasy I & II: Dawn of Souls'
# No exact match found for 'Mega Man ZX'
# No exact match found for 'Metal Gear 2: Solid Snake'
# Game ID for 'The Missing: J.J. Macfield and the Island of Memories' is 6739
# No exact match found for 'Silent Hill 2: Restless Dreams'
# Game ID for 'Friday the 13th: The Game' is 4276
# Game ID for 'Quake II' is 15352
# No exact match found for 'NBA Jam'
# No exact match found for 'Final Fantasy X HD Remaster'
# Game ID for 'Mario vs. Donkey Kong' is 15498
# Game ID for 'Kenshi' is 7007
# No exact match found for 'Remember Me'
# No exact match found for 'Alpha Protocol'
# Game ID for 'Indivisible' is 8376
# Game ID for 'Jazzpunk' is 667
# No exact match found for 'Need for Speed: Hot Pursuit'
# Game ID for 'The House in Fata Morgana: A Requiem for Innocence' is 8774
# Game ID for 'Phantom Brigade' is 14374
# No exact match found for 'Altered Beast'
# Game ID for 'Broken Age' is 29
# Game ID for 'Telling Lies' is 8168
# Game ID for 'Saints Row: Gat Out of Hell' is 128
# No exact match found for 'Ratchet & Clank: Size Matters'
# No exact match found for 'Mario Hoops 3-on-3'
# No exact match found for 'Mario Power Tennis'
# Game ID for 'Keep Talking and Nobody Explodes' is 2519
# Game ID for 'The Swapper' is 232
# No exact match found for 'Ms. Pac-Man'
# No exact match found for 'Gun'
# No exact match found for 'Naruto: Ultimate Ninja 3'
# No exact match found for 'The Ultimate Doom'
# No exact match found for 'Superman: The New Superman Adventures'
# Game ID for 'Ruiner' is 4762
# No exact match found for 'The Lord of the Rings: The Two Towers'
# No exact match found for 'Dragon Quest II: Luminaries of the Legendary Line'
# Game ID for 'Chivalry: Medieval Warfare' is 2045
# Game ID for 'FIFA 14' is 318
# Game ID for 'Bit.Trip Runner' is 10701
# No exact match found for 'Pokémon Pinball: Ruby & Sapphire'
# No exact match found for 'FIFA 13'
# Game ID for 'La-Mulana' is 9145
# Game ID for 'The Warriors' is 3164
# Game ID for 'Mortal Kombat XL' is 2386
# Game ID for 'Anonymous;Code' is 15452
# No exact match found for 'Higurashi no Naku Koro ni: Chapter 2 - Watanagashi'
# No exact match found for 'Aokana: Four Rhythms Across the Blue'
# Game ID for 'Shantae and the Seven Sirens' is 9529
# No exact match found for 'Mega Man ZX Advent'
# No exact match found for 'Peggle Deluxe'
# No exact match found for 'Slither.io'
# No exact match found for 'Twisted Metal'
# No exact match found for 'Dragon Age: Origins - Awakening'
# No exact match found for 'Parasite Eve II'
# No exact match found for 'The Jackbox Party Pack'
# No exact match found for 'Tom Clancy's Splinter Cell: Pandora Tomorrow'
# No exact match found for 'Payday: The Heist'
# No exact match found for 'Pokémon Rumble Blast'
# No exact match found for 'Nicktoons Unite!'
# Game ID for 'Ruined King: A League of Legends Story' is 12358
# Game ID for 'Picross S3' is 7629
# No exact match found for 'Lisa the Joyful'
# No exact match found for 'The King of Fighters '98'
# No exact match found for 'Kingdoms of Amalur: Reckoning'
# No exact match found for 'Grand Theft Auto'
# No exact match found for 'Europa Universalis IV'
# No exact match found for 'Guitar Hero 5'
# No exact match found for 'Silent Hill: Homecoming'
# Game ID for 'Mighty No. 9' is 1554
# No exact match found for 'Dragon Ball GT: Final Bout'
# No exact match found for 'Killzone 3'
# No exact match found for 'WWE SmackDown vs. Raw 2008'
# Game ID for 'Children of Morta' is 8217
# No exact match found for 'The Godfather'
# No exact match found for 'Billy Hatcher and the Giant Egg'
# No exact match found for 'Tekken Tag Tournament 2'
# Game ID for 'Bloons TD 5' is 6241
# No exact match found for 'JoJo's Bizarre Adventure'
# No exact match found for 'Another World'
# Game ID for 'Back to the Future: The Game' is 1575
# Game ID for 'Team Sonic Racing' is 7124
# No exact match found for 'Dragon's Dogma'
# Game ID for 'Baldur's Gate 3' is 9136
# Game ID for 'The LEGO Movie Videogame' is 289
# Game IDs saved to data/game_ids.json

# %% [markdown]
# We had to filter out some of the Game Titles, because not everything can be found by the OpenCritic API, let's look how many we have left since the beginning:

# %%
print(f"Amount of Games before filtering: {len(game_names)}")
print(f"Amount of Games after filtering: {len(filtered_game_names)}")
# Out:
# Amount of Games before filtering: 1098
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 print(f"Amount of Games before filtering: {len(game_names)}")
# ----> 2 print(f"Amount of Games after filtering: {len(filtered_game_names)}")
#
# NameError: name 'filtered_game_names' is not defined

# %% [markdown]
# Now for the next step, we need to gather the Gaming Platforms from the API:

# %%
url = "https://opencritic-api.p.rapidapi.com/platform"

headers = {
    "X-RapidAPI-Host": "opencritic-api.p.rapidapi.com",
    "X-RapidAPI-Key": "64686b9a75msha576b74f8ff0b56p1a63ebjsnf20f69b4fac9"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    platforms = response.json()
else:
    print(f"Error searching for Platforms: ", response.status_code)

with open("data/platforms.json", "w") as json_file:
    json.dump(data, json_file)

print("Gaming Platforms saved to data/platforms.json")
# Out:
# Gaming Platforms saved to data/platforms.json

# %% [markdown]
# We lost half of the Dataset, but this is still a good number to work with.

# %% [markdown]
# Now we are going to collect all the needed Data for each of the outlet IDs as well as the average score from every critic from every game. Since the API only collects 20 Reviews at a Time, we will need a loop to go through 20 sets, then skip the 20 already found and start a new search, until we have gathered each review for each game:

# %%
# API key used for the API access
api_key = "64686b9a75msha576b74f8ff0b56p1a63ebjsnf20f69b4fac9"

# List of outlet IDs
outlets = {
    "IGN": 56,
    "PC Gamer": 162,
    "GamesRadar+": 91,
    "Metro GameCentral": 75,
    "Eurogamer": 114,
    "Easy Allies": 394,
    "Game Informer": 35,
    "Forbes": 290,
    "GameSpot": 32,
    "Game Rant": 60
}

# Function to load platforms data from platforms.json
def load_platforms_data(filename="platforms.json"):
    with open(filename, 'r') as f:
        platforms_data = json.load(f)
    platforms_map = {platform['id']: platform['name'] for platform in platforms_data}
    return platforms_map

# Function to get reviews for each game ID
def get_reviews_for_games(game_ids, api_key, sort_by="newest"):
    all_reviews = []

    for game_name, game_id in game_ids:
        game_reviews = []
        skip = 0

        while True:
            url = f"https://opencritic-api.p.rapidapi.com/reviews/game/{game_id}?skip={skip}&sort={sort_by}"

            headers = {
                "X-RapidAPI-Host": "opencritic-api.p.rapidapi.com",
                "X-RapidAPI-Key": api_key
            }

            response = requests.get(url, headers=headers)

            if response.status_code == 200:
                data = response.json()
                if not data:
                    break  # No more reviews to fetch
                game_reviews.extend(data)
                skip += 20
            else:
                print(f"Error for game ID '{game_id}' at skip={skip}: ", response.status_code)
                break

        all_reviews.extend([(game_name, review) for review in game_reviews])
        print(f"Collected {len(game_reviews)} reviews for game '{game_name}'")

    return all_reviews

# Function to process reviews and save to JSON
def process_and_save_reviews(reviews, outlets, platforms_map, path="data/opencritic_reviews.json"):
    result = {}

    # Dictionary to store platform scores and counts
    platform_scores = {}
    platform_counts = {}

    for game_name, review in reviews:
        outlet_id = review['Outlet']['id']
        outlet_name = review['Outlet']['name']
        score = review.get('score')
        created_at = review['createdAt'][:10]  # Extract the date part (YYYY-MM-DD)
        authors = review.get('Authors', [])
        author_name = authors[0]['name'] if authors else None

        # Extract platforms from the review
        platforms = review.get('Platforms', [])
        if platforms:
            for platform in platforms:
                platform_id = platform['id']
                if platform_id in platforms_map:
                    platform_name = platforms_map[platform_id]
                    if platform_name not in platform_scores:
                        platform_scores[platform_name] = []
                        platform_counts[platform_name] = 0
                    if isinstance(score, (int, float)):
                        platform_scores[platform_name].append(score)
                        platform_counts[platform_name] += 1

        if game_name not in result:
            result[game_name] = {"outlets": {}, "platforms": {}, "average_score": None}

        if outlet_id in outlets.values():
            # Check if the score is a valid number
            if isinstance(score, (int, float)) and score is not None:
                result[game_name]["outlets"][outlet_name] = {
                    "score": score,
                    "review_url": review['externalUrl'],
                    "created_at": created_at,
                    "author": author_name  # Include author's name if available
                }

    # Calculate average scores for each platform
    for platform_name, scores in platform_scores.items():
        if scores:
            avg_score = sum(scores) / len(scores)
            result[game_name]["platforms"][platform_name] = {
                "average_score": avg_score,
                "count": platform_counts[platform_name]
            }

    # Calculate average score for the game
    all_scores = [outlet_data["score"] for outlet_data in result[game_name]["outlets"].values() if isinstance(outlet_data["score"], (int, float))]
    if all_scores:
        result[game_name]["average_score"] = sum(all_scores) / len(all_scores)

    # Save to JSON
    with open(path, 'w') as json_file:
        json.dump(result, json_file, indent=4)
    print(f"Reviews data saved to {path}")

# Load game IDs from JSON file
# with open("data/game_ids.json", "r") as json_file:
    # data = json.load(json_file)
    # game_ids = data["game_ids"]

# mocking data; for testing
game_ids = [["Elden Ring", 12090]]

# Load platforms data
platforms_map = load_platforms_data("data/platforms.json")

# Get reviews for each game
all_reviews = get_reviews_for_games(game_ids, api_key)

# Process reviews and save to JSON
process_and_save_reviews(all_reviews, outlets, platforms_map)
# Out:
# KeyboardInterrupt

# %% [markdown]
# ## Web Scraping

# %%
# Load game names from JSON file
with open("data/game_ids.json", "r") as json_file:
    df_names = json.load(json_file)
    filtered_game_names = df_names["filtered_game_names"]

# List of game names to scrape (parameter: filtered_game_names) mocking data
# filtered_game_names = [
    # "grand theft AUTO v",
    # "Elden Ring",
    # "Wii Sports",
    # "The Legend Of Zelda: Breath of The Wild",
    # "Cooking Mama",
    # "StardEW valley",
    # "Resident Evil 5",
    # "Unga Bunga doogaloo"
    # Add more game names here
# ]

# Base URL
base_url = "https://www.backloggd.com/games/"

# Initialize a list to store game names, scores, plays, and genres
data = []

# Loop through each game name in the list
for game_name in filtered_game_names:
    # Remove any colons from the game name
    game_name_clean = game_name.replace(':', '')
    
    # Create the URL by replacing spaces with hyphens and converting to lowercase
    url = f"{base_url}{game_name_clean.replace(' ', '-').lower()}/"
    
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the div with id 'score'
        score_div = soup.find('div', id='score')
        
        # Initialize variables for score, plays, and genres
        score_percentage = None
        plays_count = None
        genres = []
        
        # If the score_div is found, extract the score
        if score_div:
            score = score_div.find('h1').text.strip()
            try:
                # Convert score to float and divide by 5 to get the percentage
                score_percentage = float(score) / 5 * 100
            except ValueError:
                # Handle the case where the score is not a valid number
                print(f"Invalid score for game: {game_name}")
        
        # Find the plays counter
        plays_counter = soup.find('a', class_='plays-counter', href=True)
        
        # If the plays_counter is found, extract the plays count
        if plays_counter:
            plays_text = plays_counter.find_all('p')[-1].text.strip()
            plays_count = plays_text
        
        # Find all genre tags
        genre_tags = soup.find_all('p', class_='genre-tag')
        
        # Extract genres if they exist
        for genre_tag in genre_tags:
            genre = genre_tag.text.strip()
            genres.append(genre)
        
        # Only append if at least one of score, plays, or genres is not None
        if score_percentage is not None or plays_count is not None or genres:
            data.append({
                'Game Name': game_name, 
                'Score': score_percentage, 
                'Plays': plays_count, 
                'Genres': ', '.join(genres) if genres else None
            })
    else:
        print(f"Failed to retrieve data for game: {game_name}")

# Create a DataFrame from the data list
df = pd.DataFrame(data)

# Save the DataFrame to a Parquet file
df.to_parquet('data/user_scores.parquet', index=False)

print("Data saved to user_scores.parquet")
# Out:
# Invalid score for game: Hades
# Failed to retrieve data for game: Enter the Gungeon
# Failed to retrieve data for game: Super Smash Bros. for Wii U
# Invalid score for game: Lunistice
# Failed to retrieve data for game: Gungrave G.O.R.E
# Failed to retrieve data for game: The Missing: J.J. Macfield and the Island of Memories
# Invalid score for game: Bit.Trip Runner
# Data saved to user_scores.parquet

# %% [markdown]
# Now let's take a look at the actual file we just created, there may be some wrongly gathered data:

# %%
# Read the Parquet file
df = pd.read_parquet('data/user_scores.parquet')

print(df.count())
print(df[df.isnull().any(axis=1)])
# Display the DataFrame
print(df.min())
print(df.head())
# Out:
# Game Name    483
# Score        480
# Plays        483
# Genres       483
# dtype: int64
#            Game Name  Score Plays                             Genres
# 1              Hades    NaN     4                            Shooter
# 241        Lunistice    NaN     2  Adventure, Arcade, Indie, Shooter
# 471  Bit.Trip Runner    NaN     0          Adventure, Indie, Shooter
# Game Name    428: Shibuya Scramble
# Score                         28.0
# Plays                            0
# Genres                   Adventure
# dtype: object
#                                  Game Name  Score Plays  \
# 0                               Elden Ring   90.0   50K
# 1                                    Hades    NaN     4
# 2  The Legend of Zelda: Breath of the Wild   88.0   66K
# 3                                Undertale   86.0   58K
# 4                            Hollow Knight   88.0   49K
#
#                                        Genres
# 0                              Adventure, RPG
# 1                                     Shooter
# 2                      Adventure, Puzzle, RPG
# 3  Adventure, Indie, RPG, Turn Based Strategy
# 4                  Adventure, Indie, Platform

# %% [markdown]
# Looks like we got three datasets with NaN value, lets remove those. Also Looks like the score is not consistent with our previously gathered dataframes, let's round these so we can get integers. The plays column is also very inconsistent, lets remove the 'k' and multiply the number by 1000 to get consistent numbers:

# %%
# Drop all NAs from the DataFrame
df.dropna(inplace=True)

# Round the scores to integers
df['Score'] = df['Score'].round().astype(int)

# Function to process the plays count
def process_plays(plays):
    if pd.isna(plays):
        return plays
    if 'K' in plays:
        return int(float(plays.replace('K', '')) * 1000)
    return int(plays)

# Apply the function to the Plays column
df['Plays'] = df['Plays'].apply(process_plays)

# Save the cleaned DataFrame to a new Parquet file
df.to_parquet('data/cleaned_user_scores.parquet', index=False)

print("Cleaned data saved to cleaned_user_scores.parquet")
# Out:
# Cleaned data saved to cleaned_user_scores.parquet

# %%
# Read the Parquet file
df = pd.read_parquet('data/cleaned_user_scores.parquet')

print(df.count())
print(df[df.isnull().any(axis=1)])
# Display the DataFrame
print(df.min())
print(df.head())
# Out:
# Game Name    480
# Score        480
# Plays        480
# Genres       480
# dtype: int64
# Empty DataFrame
# Columns: [Game Name, Score, Plays, Genres]
# Index: []
# Game Name    428: Shibuya Scramble
# Score                           28
# Plays                           52
# Genres                   Adventure
# dtype: object
#                                  Game Name  Score  Plays  \
# 0                               Elden Ring     90  50000
# 1  The Legend of Zelda: Breath of the Wild     88  66000
# 2                                Undertale     86  58000
# 3                            Hollow Knight     88  49000
# 4                                Minecraft     86  74000
#
#                                        Genres
# 0                              Adventure, RPG
# 1                      Adventure, Puzzle, RPG
# 2  Adventure, Indie, RPG, Turn Based Strategy
# 3                  Adventure, Indie, Platform
# 4                        Adventure, Simulator

# %% [markdown]
# ### Kafka/Spark alternative

# %% [markdown]
# There seems to be a client side error that prevents us from using Kafka/Spark to edit the data, here is the code for this anyway, it should work on a suitable device:

# %%
# Initialize SparkSession
spark = SparkSession.builder \
    .appName("ReadParquetAndStreamToKafka") \
    .getOrCreate()

# Read Parquet file into a DataFrame
df = spark.read.parquet("data/user_scores.parquet")

# Show the DataFrame schema and content
df.printSchema()
df.show(truncate=False)

# %%
# Write data to Kafka topic
kafka_broker = "localhost:29092"
kafka_topic = "user_scores_topic"

df.withColumnRenamed("Game Name", "GameName") \
  .selectExpr("CAST(GameName AS STRING) AS key", "to_json(struct(*)) AS value") \
  .write \
  .format("kafka") \
  .option("kafka.bootstrap.servers", kafka_broker) \
  .option("topic", kafka_topic) \
  .save()

# %%
# Initialize SparkSession
spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .getOrCreate()

# Define schema for Kafka message
schema = StructType() \
    .add("Game Name", StringType()) \
    .add("Score", DoubleType()) \
    .add("Plays", StringType()) \
    .add("Genres", StringType())

# Read from Kafka
kafka_stream = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:29092") \
    .option("subscribe", "user_scores_topic") \
    .load()

# Convert value from binary to string
kafka_stream = kafka_stream.selectExpr("CAST(value AS STRING)")

# Parse JSON data
parsed_stream = kafka_stream.select(from_json(col("value"), schema).alias("data")).select("data.*")

# Drop NA values
parsed_stream = parsed_stream.dropna()

# Round the scores
parsed_stream = parsed_stream.withColumn("Score", expr("ROUND(Score)").cast(IntegerType()))

# Function to process plays count
def process_plays(plays):
    if 'K' in plays:
        return int(float(plays.replace('K', '')) * 1000)
    return int(plays)

# Apply the function to Plays column
processed_stream = parsed_stream.withColumn("Plays", expr("process_plays(Plays)").cast(IntegerType()))

# Write processed data to Parquet file
query = processed_stream.writeStream \
    .outputMode("append") \
    .format("parquet") \
    .option("checkpointLocation", "checkpoints/user_scores") \
    .start("data/cleaned_user_scores.parquet")

# Await termination
query.awaitTermination()
