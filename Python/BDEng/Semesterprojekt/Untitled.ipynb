# %%
# !npm install -g ijavascript
ijsinstall
# Out:
# npm WARN deprecated uuid@3.4.0: Please upgrade  to version 7 or higher.  Older versions may use Math.random() in certain circumstances, which is known to be problematic.  See https://v8.dev/blog/math-random for details.
# npm WARN cleanup Failed to remove some directories [
# npm WARN cleanup   [
# npm WARN cleanup     'C:\\Users\\Startklar\\AppData\\Roaming\\npm\\node_modules\\ijavascript\\node_modules',
# npm WARN cleanup     [Error: EPERM: operation not permitted, rmdir 'C:\Users\Startklar\AppData\Roaming\npm\node_modules\ijavascript\node_modules\nel\lib'] {
# npm WARN cleanup       errno: -4048,
# npm WARN cleanup       code: 'EPERM',
# npm WARN cleanup       syscall: 'rmdir',
# npm WARN cleanup       path: 'C:\\Users\\Startklar\\AppData\\Roaming\\npm\\node_modules\\ijavascript\\node_modules\\nel\\lib'
# npm WARN cleanup     }
# npm WARN cleanup   ]
# npm WARN cleanup ]
# npm ERR! code 1
# ...

# %%
# !git clone https://github.com/ChrisMichaelPerezSantiago/metacritic
# !cd metacritic
# !npm install

# %%
# !npx tsc

# %%
import express from 'express';
import { searchGames } from './path/to/metacritic/api';

const app = express();
const port = 3000;

app.get('/searchGames', async (req, res) => {
  const query = req.query.query as string;
  try {
    const result = await searchGames(query);
    res.json(result);
  } catch (error) {
    res.status(500).json({ error: error.message });
  }
});

app.listen(port, () => {
  console.log(`Server is running at http://localhost:${port}`);
});
# Out:
#   Cell In[9], line 1
#     import express from 'express';
#                    ^
# SyntaxError: invalid syntax

# %%
npx tsc server.ts
# Out:
#   Cell In[2], line 1
#     npx tsc server.ts
#         ^
# SyntaxError: invalid syntax

# %%
node server.js

# %%
import requests

query = "Elden Ring"
response = requests.get(f'http://localhost:3000/searchGames?query={query}')

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
