# %% [markdown]
# #### Work with SQL and JSON on a Postgres-Database
# Follow these steps:
#
# 	1. use "docker-compose" of the file "Postgres-Docker.zip" to start a Postgres Database Server
# 	2. start DataGrip and set a connection to the Postgres Server (see credentials in the docker-compose file)
# 	3. copy music-store.sql from host to container
# 	4. execute music-store.sql and create music-store tables
# 	5. check tables in Postgres server in DataGrip
# 	6. copy library.json from host to container
# 	7. create table jtracks and copy data from library.json
# 	8. check tables in Postgres server in DataGrip
# 	9. remove copied files from container
# 	10. open a console window in the Postgres Server in DataGrip
# 	11. to get a better overview about the tables (we will actually need only a few of them) check out the "music-store-DB-diagram"
# 	12. copy all statements of the file "JSON-Demo.sql" to the DataGrip console and play with the given select statements (which allow to address the JSON parts of the data)
# 	13. watch the changes done from Python-Code in DataGrip

# %% [markdown]
# ##### Music store RDM
# <img src="music-store-DB-diagram_hell.png">

# %% [markdown]
# #### Start docker container

# %%
# !docker-compose -f docker-compose/Postgres-Docker/docker-compose.yml -p postgres up -d
# Out:
#  Network postgres_default  Creating
#  Network postgres_default  Created
#  Volume "postgres_database-data"  Creating
#  Volume "postgres_database-data"  Created
#  Container postgres-db-1  Creating
#  Container postgres-db-1  Created
#  Container postgres-db-1  Starting
#  Container postgres-db-1  Started

# %%
# !docker ps
# !echo --------------------
# !docker volume ls
# !echo --------------------
# !docker network ls
# Out:
# CONTAINER ID   IMAGE      COMMAND                  CREATED         STATUS         PORTS                    NAMES
# 508c245b2767   postgres   "docker-entrypoint.sâ€¦"   8 seconds ago   Up 6 seconds   0.0.0.0:5432->5432/tcp   postgres-db-1
# --------------------
# DRIVER    VOLUME NAME
# local     1d61b7ecf33710ce9267129c0e0a5494f66f0700a36ac63a5c269db55af13024
# local     6c4fa7ad605cfaa3512f758870728c7543def00f90f411acd280f5d2ffb93fa7
# local     8b544837e7c1cfea1e82c8fe63b340592d8adef8e5b7fca6f653cdc878bb0652
# local     35df70ea511717fa448e9afdf7e5810c0fdf484c2fe47bdb96504420b25fc064
# local     44a85378c2d866d8b3bb069d1a16bac77ef2ec908854ca42e47b81308efb38ba
# local     48d8285916ade33bf0dfea6a3d95ef015d714392aec13ea45e89166cbd5f61c0
# local     85a0d7c31e171a6c35245e02c82ab167eaa3a6ab50bcdc833249a796ebeb5233
# local     237a6ca4a3e678f91e10010500ae60c2e9dea5ad359057d8260d8e4f1ca57e3a
# local     515d36cfe1808755fb5fbf129a765c12f6d7239989e232d436ea16504df983c7
# local     29875caee0bb01b3d542fb3a8a9f94d1050a595cc4ebe0e908dd298ea30e0655
# local     a3c1c99d24ff50821e813c0bcc68c52e4155fc0fea9dead5f73d67946357d774
# local     a7ef8b7228ae350146a752688ee6f1f750a490ff199f4b946ae352f49e36a49b
# local     abb25dbf251e7fb7831fb73bf1a4c079d23947de5c697baa1e07bae0d180e09d
# local     b7260bd50a99e49884860e7c3b45980dbe1896b30aa8f2cdb8ac61a39104cf2f
# local     be7b71a1b631eb956dfffb756b245475a3999586d757ae6a053e2521d1905cde
# local     bf6bfbf1df1e8b3b84751146cbd5641ceb5f9350757c01afc47b78ef7294ac9e
# local     cb1a6cc2fa8ea3e27d5e7adcf635324fefae744b793b786f79c504391a2bfd8e
# local     e7a9a0fcbcd86dae5166305c0ecbc1a0aa3aa854d463efcfc4c1fbe022059a84
# local     f2e74d745327ed9b481d3bf31f81bad49621366ffeace61f9d4c7f39609f22e3
# local     f7b4d69027f06a06abc624f2aa5aec3f99db05e94a39a4ce439434ac6d1ccf47
# local     f47f12a809526f3897d0e28bb3f12addb662d4e601de728c46b7443fbd3d7615
# local     mongodb_data
# local     mysql_dbeaver_mysql_volume
# local     myvolume
# local     neo4j_data
# local     neo4j_movie
# local     postgres_database-data
# --------------------
# NETWORK ID     NAME               DRIVER    SCOPE
# ef1a29c9eb07   bridge             bridge    local
# 3408928eb3d5   host               host      local
# ba86ebb06783   none               null      local
# 894ec2a376df   postgres_default   bridge    local

# %% [markdown]
# #### Create music-store schema

# %%
# copy music-store.sql from host to container
# !docker cp music-store.sql postgres-db-1:/music-store.sql

# %%
# Create music-store tables
# !docker exec -i postgres-db-1 bash -c "psql -U admin -d postgres < music-store.sql"

# %% [markdown]
# #### Create jtracks table

# %%
# copy library.json from host to container
# !docker cp library.json postgres-db-1:/library.json

# %%
# Create table jtraks in postgres db
# !docker exec -i postgres-db-1 bash -c "psql -U admin -d postgres -c 'CREATE TABLE IF NOT EXISTS jtracks(id SERIAL, body JSONB);'"

# %%
# copy json data to table
# !docker exec -i postgres-db-1 bash -c "psql -U admin -d postgres -c \"\copy jtracks(body)FROM '/library.json' WITH CSV QUOTE E'\x01' DELIMITER E'\x02';\""

# %%
# delete copied file from container
# !docker exec -i postgres-db-1 bash -c "rm /music-store.sql /library.json"

# %% [markdown]
# #### Stop docker container

# %%
# !docker-compose -f docker-compose/Postgres-Docker/docker-compose.yml -p postgres down

# %% [markdown]
# ##### Remove volume

# %%
# !docker volume rm postgres_database-data

# %%
# !docker ps
# !echo --------------------
# !docker volume ls
# !echo --------------------
# !docker network ls
