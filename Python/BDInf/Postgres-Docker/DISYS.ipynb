# %%
# app.py in Visual Studio Code

from flask import Flask

app = Flask(__name__)

@app.route('/store')
def store():

    r = requests.get('http://localhost:8080/sales')

    sales = r.json()

    number_of_sales = len(sales)

    return '<h2> Currently there are ' + number_of_sales + ' sales!</h2>'
   ## return sales.text 
   ## return r.text
   ## return '<h1>Store</h1>'

# !flask --app DISYS run
# Out:
# Usage: flask run [OPTIONS]
# Try 'flask run --help' for help.
#
# Error: Could not import 'DISYS'.

# %%
# flask run (nur wenn die Python datei app.py heißt, sonst flask --app DATEINAME run - DATEINAME hier ohne dateityp (.py)) im Terminal

# %%
# !flask run
